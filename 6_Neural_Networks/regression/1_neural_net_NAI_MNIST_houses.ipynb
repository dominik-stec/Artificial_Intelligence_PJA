# %% [markdown]
# """
#
# author: Dominik Stec,
#
# index: s12623,
#
# email: s12623@pja.edu.pl
#
# To run module:
#
# import module into Google Colaboratory notebook and run.
#
# This module predict price of house according to house specification values.
#
# Keras model is build as regression type and contains two types of regression neural network architecture.
#
# """

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
import random
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# **First model**

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.boston_housing.load_data(
    path="boston_housing.npz", test_split=0.2, seed=113
)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(y_test[:])
# Out:
# (404, 13)
# (404,)
# (102, 13)
# (102,)
# [ 7.2 18.8 19.  27.  22.2 24.5 31.2 22.9 20.5 23.2 18.6 14.5 17.8 50.
#  20.8 24.3 24.2 19.8 19.1 22.7 12.  10.2 20.  18.5 20.9 23.  27.5 30.1
#   9.5 22.  21.2 14.1 33.1 23.4 20.1  7.4 15.4 23.8 20.1 24.5 33.  28.4
#  14.1 46.7 32.5 29.6 28.4 19.8 20.2 25.  35.4 20.3  9.7 14.5 34.9 26.6
#   7.2 50.  32.4 21.6 29.8 13.1 27.5 21.2 23.1 21.9 13.  23.2  8.1  5.6
#  21.7 29.6 19.6  7.  26.4 18.9 20.9 28.1 35.4 10.2 24.3 43.1 17.6 15.4
#  16.2 27.1 21.4 21.5 22.4 25.  16.6 18.6 22.  42.8 35.1 21.5 36.  21.9
#  24.1 50.  26.7 25. ]

# %%
model = Sequential()
model.add(Dense(units=1024, activation='relu', input_shape=(13, )))
model.add(Dropout(0.2))
model.add(Dense(units=512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.summary()
print()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_67 (Dense)             (None, 1024)              14336
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_68 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 1)                 513
# ...
# Total params: 539,649
# Trainable params: 539,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 13/13 [==============================] - 0s 13ms/step - loss: 334.5216 - mean_absolute_error: 334.5216 - val_loss: 8.7850 - val_mean_absolute_error: 8.7850
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 8.2392 - mean_absolute_error: 8.2392 - val_loss: 7.9989 - val_mean_absolute_error: 7.9989
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 8.3254 - mean_absolute_error: 8.3254 - val_loss: 6.9068 - val_mean_absolute_error: 6.9068
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 6.8053 - mean_absolute_error: 6.8053 - val_loss: 6.0969 - val_mean_absolute_error: 6.0969
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 5.6495 - mean_absolute_error: 5.6495 - val_loss: 5.6435 - val_mean_absolute_error: 5.6435
# Epoch 6/20
# ...

# %%
i = random.randrange(0, len(y_test))

print('real house price: ', y_test[i])

pred_price = model.predict(X_test[i].reshape(1, 13))
print('predict house price: {price:.2f}'.format(price = pred_price[0][0]))
# Out:
# real house price:  12.0
# predict house price: 14.64

# %% [markdown]
# **Second model**

# %%
model = Sequential()
model.add(Dense(units=128, activation='relu', input_shape=(13, )))
model.add(Dropout(0.1))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=1))
model.summary()
print()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='mean_squared_error',
              metrics=['mean_squared_error'])
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_73 (Dense)             (None, 128)               1792
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_74 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_75 (Dense)             (None, 1)                 65
# ...
# Total params: 10,113
# Trainable params: 10,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 13ms/step - loss: 2944.9666 - mean_squared_error: 2944.9666 - val_loss: 111.4351 - val_mean_squared_error: 111.4351
# Epoch 2/20
# 13/13 [==============================] - 0s 5ms/step - loss: 186.7387 - mean_squared_error: 186.7387 - val_loss: 83.2601 - val_mean_squared_error: 83.2601
# Epoch 3/20
# 13/13 [==============================] - 0s 5ms/step - loss: 102.3432 - mean_squared_error: 102.3432 - val_loss: 69.9835 - val_mean_squared_error: 69.9835
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 93.4900 - mean_squared_error: 93.4900 - val_loss: 60.3167 - val_mean_squared_error: 60.3167
# Epoch 5/20
# 13/13 [==============================] - 0s 5ms/step - loss: 96.7907 - mean_squared_error: 96.7907 - val_loss: 76.8472 - val_mean_squared_error: 76.8472
# Epoch 6/20
# ...

# %%
i = random.randrange(0, len(y_test))

print('real house price: ', y_test[i])

pred_price = model.predict(X_test[i].reshape(1, 13))
print('predict house price: {price:.2f}'.format(price = pred_price[0][0]))
# Out:
# real house price:  14.1
# predict house price: 12.37
